# %% [markdown]
# ### Step 1: Import the libraries for VGG16

# %%
import keras,os, pathlib
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from sklearn import metrics
import numpy as np
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from keras.models import load_model
from collections import OrderedDict

# %%
train_dir = "C:/Users/alexa/Documents/Studium/Bachelor/Data2/trainimages/"
test_dir = "C:/Users/alexa/Documents/Studium/Bachelor/Data2/testimages/"

data_dir = pathlib.Path(train_dir)
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))
print(class_names)


# Rescale
train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

trdata=ImageDataGenerator()
traindata = trdata.flow_from_directory(directory="C:/Users/alexa/Documents/Studium/Bachelor/Data2/trainimages/",target_size=(224,224), batch_size=32, class_mode='categorical')
tsdata=ImageDataGenerator()
testdata = tsdata.flow_from_directory(directory="C:/Users/alexa/Documents/Studium/Bachelor/Data2/testimages/", target_size=(224,224), batch_size=32, class_mode='categorical')

# augumented data
train_datagen_augmented = ImageDataGenerator(rescale=1/255.,
                                            shear_range=0.2,
                                            zoom_range=0.2,
                                            horizontal_flip=True)

#rotation_range=20,
#width_shift_range=0.2,
#height_shift_range=0.2,
# Load data
train_datagen_augmented2 = ImageDataGenerator(shear_range=0.2,
                                            zoom_range=0.2,
                                            horizontal_flip=True)
train_data_augmented = train_datagen_augmented.flow_from_directory(train_dir,
                                              target_size=(224,224),
                                              batch_size=32,
                                              class_mode='categorical',
                                              shuffle = False)
test_data = test_datagen.flow_from_directory(test_dir,
                                            target_size=(224,224),
                                            batch_size=32,
                                            class_mode='categorical',
                                            shuffle = False)
# Out:
# ['blues' 'classical' 'country' 'disco' 'hiphop' 'jazz' 'metal' 'pop'
#  'reggae' 'rock']
# Found 799 images belonging to 10 classes.
# Found 200 images belonging to 10 classes.
# Found 799 images belonging to 10 classes.
# Found 200 images belonging to 10 classes.

# %%
model = Sequential()
model.add(Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same",activation="relu"))
model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Flatten())
model.add(Dense(units=256, activation="relu"))
model.add(Dense(units=128, activation="relu"))
model.add(Dense(units=10, activation="softmax"))

# %%
from keras.optimizers import Adam
opt=Adam(learning_rate=1e-6)
model.compile(optimizer=opt, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 224, 224, 64)      1792
#
#  conv2d_14 (Conv2D)          (None, 224, 224, 64)      36928
#
#  max_pooling2d_5 (MaxPooling  (None, 112, 112, 64)     0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 112, 112, 128)     73856
#
#  conv2d_16 (Conv2D)          (None, 112, 112, 128)     147584
#
#  max_pooling2d_6 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_18 (Conv2D)          (None, 56, 56, 256)       590080
#
#  conv2d_19 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_7 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  max_pooling2d_8 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_9 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_3 (Dense)             (None, 256)               6422784
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 21,171,658
# Trainable params: 21,171,658
# Non-trainable params: 0
# _________________________________________________________________

# %%
#from keras.callbacks import ModelCheckpoint, EarlyStopping
#checkpoint = ModelCheckpoint("vgg16_1.h5", monitor='accuracy', verbose = 1, save_best_only=True, save_weights_only=False, mode='auto', save_freq=1)
mc=ModelCheckpoint("vgg16_best_model_1.h5", monitor='val_accuracy',mode='max',save_best_only=True)
#early=EarlyStopping(monitor='accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
hist=model.fit(traindata, epochs=150, steps_per_epoch=len(traindata), validation_data=test_data, validation_steps=len(testdata), verbose=1,callbacks=[mc])
# Out:
# Epoch 1/150
# 25/25 [==============================] - 392s 16s/step - loss: 2.3057 - accuracy: 0.0989 - val_loss: 2.3025 - val_accuracy: 0.1100
# Epoch 2/150
# 25/25 [==============================] - 399s 16s/step - loss: 2.2683 - accuracy: 0.1715 - val_loss: 2.3024 - val_accuracy: 0.2050
# Epoch 3/150
# 25/25 [==============================] - 408s 16s/step - loss: 2.2400 - accuracy: 0.2428 - val_loss: 2.3023 - val_accuracy: 0.2400
# 25/25 [==============================] - 796s 32s/step - loss: 1.6859 - accuracy: 0.4981 - val_loss: 2.2991 - val_accuracy: 0.3950
# Epoch 24/150
# 25/25 [==============================] - 795s 32s/step - loss: 1.6680 - accuracy: 0.5006 - val_loss: 2.2988 - val_accuracy: 0.3950
# Epoch 25/150
# 25/25 [==============================] - 790s 32s/step - loss: 1.6381 - accuracy: 0.5282 - val_loss: 2.2987 - val_accuracy: 0.4250
# Epoch 26/150
# 25/25 [==============================] - 798s 32s/step - loss: 1.6195 - accuracy: 0.5131 - val_loss: 2.2985 - val_accuracy: 0.3850
# Epoch 27/150
# 25/25 [==============================] - 803s 32s/step - loss: 1.5940 - accuracy: 0.5131 - val_loss: 2.2983 - val_accuracy: 0.4300
# Epoch 28/150
# 25/25 [==============================] - 807s 32s/step - loss: 1.5762 - accuracy: 0.5257 - val_loss: 2.2981 - val_accuracy: 0.4450
# Epoch 29/150
# 25/25 [==============================] - 803s 32s/step - loss: 1.5560 - accuracy: 0.5344 - val_loss: 2.2980 - val_accuracy: 0.4150
# Epoch 30/150
# 25/25 [==============================] - 789s 32s/step - loss: 1.5331 - accuracy: 0.5369 - val_loss: 2.2978 - val_accuracy: 0.4300
# Epoch 31/150
# 25/25 [==============================] - 809s 32s/step - loss: 1.5145 - accuracy: 0.5294 - val_loss: 2.2975 - val_accuracy: 0.4200
# Epoch 32/150
# 25/25 [==============================] - 765s 31s/step - loss: 1.4938 - accuracy: 0.5394 - val_loss: 2.2974 - val_accuracy: 0.4100
# Epoch 33/150
# 25/25 [==============================] - 411s 16s/step - loss: 1.4838 - accuracy: 0.5181 - val_loss: 2.2972 - val_accuracy: 0.4150
# Epoch 34/150
# 25/25 [==============================] - 408s 16s/step - loss: 1.4654 - accuracy: 0.5457 - val_loss: 2.2971 - val_accuracy: 0.4750
# Epoch 35/150
# 25/25 [==============================] - 409s 16s/step - loss: 1.4558 - accuracy: 0.5444 - val_loss: 2.2970 - val_accuracy: 0.4550
# Epoch 36/150
# 25/25 [==============================] - 408s 16s/step - loss: 1.4243 - accuracy: 0.5795 - val_loss: 2.2968 - val_accuracy: 0.4050
# Epoch 37/150
# 25/25 [==============================] - 411s 16s/step - loss: 1.4064 - accuracy: 0.5657 - val_loss: 2.2967 - val_accuracy: 0.4950
# Epoch 38/150
# 25/25 [==============================] - 407s 16s/step - loss: 1.3938 - accuracy: 0.5782 - val_loss: 2.2965 - val_accuracy: 0.4800
# Epoch 39/150
# 25/25 [==============================] - 420s 17s/step - loss: 1.3833 - accuracy: 0.5532 - val_loss: 2.2965 - val_accuracy: 0.4900
# Epoch 40/150
# 25/25 [==============================] - 407s 16s/step - loss: 1.3779 - accuracy: 0.5682 - val_loss: 2.2963 - val_accuracy: 0.4800
# Epoch 41/150
# 25/25 [==============================] - 417s 17s/step - loss: 1.3594 - accuracy: 0.5494 - val_loss: 2.2962 - val_accuracy: 0.4800
# Epoch 42/150
# 25/25 [==============================] - 413s 17s/step - loss: 1.3350 - accuracy: 0.5945 - val_loss: 2.2960 - val_accuracy: 0.5050
# Epoch 43/150
# Epoch 63/150
# 25/25 [==============================] - 420s 17s/step - loss: 1.1074 - accuracy: 0.6521 - val_loss: 2.2938 - val_accuracy: 0.5200
# Epoch 64/150
# 25/25 [==============================] - 419s 17s/step - loss: 1.0902 - accuracy: 0.6621 - val_loss: 2.2937 - val_accuracy: 0.5350
# Epoch 65/150
# 25/25 [==============================] - 422s 17s/step - loss: 1.0850 - accuracy: 0.6646 - val_loss: 2.2936 - val_accuracy: 0.5100
# Epoch 66/150
# 25/25 [==============================] - 421s 17s/step - loss: 1.0794 - accuracy: 0.6521 - val_loss: 2.2936 - val_accuracy: 0.5050
# Epoch 67/150
# 25/25 [==============================] - 416s 17s/step - loss: 1.0602 - accuracy: 0.6721 - val_loss: 2.2935 - val_accuracy: 0.5400
# Epoch 68/150
# 25/25 [==============================] - 411s 17s/step - loss: 1.0685 - accuracy: 0.6608 - val_loss: 2.2933 - val_accuracy: 0.5400
# Epoch 69/150
# 25/25 [==============================] - 410s 16s/step - loss: 1.0575 - accuracy: 0.6633 - val_loss: 2.2933 - val_accuracy: 0.5350
# Epoch 70/150
# 25/25 [==============================] - 416s 17s/step - loss: 1.0339 - accuracy: 0.6683 - val_loss: 2.2932 - val_accuracy: 0.5400
# Epoch 71/150
# 25/25 [==============================] - 411s 16s/step - loss: 1.0229 - accuracy: 0.6959 - val_loss: 2.2931 - val_accuracy: 0.5050
# Epoch 72/150
# 25/25 [==============================] - 413s 17s/step - loss: 1.0229 - accuracy: 0.6909 - val_loss: 2.2930 - val_accuracy: 0.4750
# Epoch 73/150
# 25/25 [==============================] - 415s 17s/step - loss: 1.0045 - accuracy: 0.6984 - val_loss: 2.2930 - val_accuracy: 0.5600
# Epoch 74/150
# 25/25 [==============================] - 420s 17s/step - loss: 0.9834 - accuracy: 0.7084 - val_loss: 2.2928 - val_accuracy: 0.5300
# Epoch 75/150
# 25/25 [==============================] - 415s 17s/step - loss: 1.0082 - accuracy: 0.6796 - val_loss: 2.2927 - val_accuracy: 0.4850
# Epoch 76/150
# 25/25 [==============================] - 417s 17s/step - loss: 0.9814 - accuracy: 0.6934 - val_loss: 2.2927 - val_accuracy: 0.5300
# Epoch 77/150
# 25/25 [==============================] - 414s 17s/step - loss: 0.9662 - accuracy: 0.7209 - val_loss: 2.2926 - val_accuracy: 0.5200
# Epoch 78/150
# 25/25 [==============================] - 415s 17s/step - loss: 0.9566 - accuracy: 0.7209 - val_loss: 2.2925 - val_accuracy: 0.5000
# Epoch 79/150
# 25/25 [==============================] - 414s 17s/step - loss: 0.9535 - accuracy: 0.7134 - val_loss: 2.2924 - val_accuracy: 0.4800
# Epoch 80/150
# 25/25 [==============================] - 414s 17s/step - loss: 0.9701 - accuracy: 0.6959 - val_loss: 2.2924 - val_accuracy: 0.5200
# Epoch 81/150
# 25/25 [==============================] - 419s 17s/step - loss: 0.9461 - accuracy: 0.7121 - val_loss: 2.2923 - val_accuracy: 0.5550
# Epoch 82/150
150
# 25/25 [==============================] - 404s 16s/step - loss: 0.6362 - accuracy: 0.8185 - val_loss: 2.2890 - val_accuracy: 0.5300
# Epoch 124/150
# 25/25 [==============================] - 409s 16s/step - loss: 0.6673 - accuracy: 0.8010 - val_loss: 2.2889 - val_accuracy: 0.5350
# Epoch 125/150
# 25/25 [==============================] - 404s 16s/step - loss: 0.6498 - accuracy: 0.8073 - val_loss: 2.2888 - val_accuracy: 0.5350
# Epoch 126/150
# 25/25 [==============================] - 410s 16s/step - loss: 0.6227 - accuracy: 0.8298 - val_loss: 2.2888 - val_accuracy: 0.5450
# Epoch 127/150
# 25/25 [==============================] - 403s 16s/step - loss: 0.6284 - accuracy: 0.8235 - val_loss: 2.2888 - val_accuracy: 0.5850
# Epoch 128/150
# 25/25 [==============================] - 403s 16s/step - loss: 0.6180 - accuracy: 0.8385 - val_loss: 2.2886 - val_accuracy: 0.5400
# Epoch 129/150
# 25/25 [==============================] - 406s 16s/step - loss: 0.6244 - accuracy: 0.8198 - val_loss: 2.2885 - val_accuracy: 0.5650
# Epoch 130/150
# 25/25 [==============================] - 403s 16s/step - loss: 0.6135 - accuracy: 0.8360 - val_loss: 2.2885 - val_accuracy: 0.5450
# Epoch 131/150
# 25/25 [==============================] - 409s 16s/step - loss: 0.6043 - accuracy: 0.8310 - val_loss: 2.2884 - val_accuracy: 0.5400
# Epoch 132/150
# 25/25 [==============================] - 402s 16s/step - loss: 0.5826 - accuracy: 0.8486 - val_loss: 2.2883 - val_accuracy: 0.5550
# Epoch 133/150
# 25/25 [==============================] - 405s 16s/step - loss: 0.5935 - accuracy: 0.8348 - val_loss: 2.2883 - val_accuracy: 0.5800
# Epoch 134/150
# 25/25 [==============================] - 401s 16s/step - loss: 0.5816 - accuracy: 0.8573 - val_loss: 2.2882 - val_accuracy: 0.5650
# Epoch 135/150
# 25/25 [==============================] - 404s 16s/step - loss: 0.5694 - accuracy: 0.8573 - val_loss: 2.2881 - val_accuracy: 0.5650
# Epoch 136/150
# 25/25 [==============================] - 403s 16s/step - loss: 0.5751 - accuracy: 0.8511 - val_loss: 2.2881 - val_accuracy: 0.5450
# Epoch 137/150
# 25/25 [==============================] - 404s 16s/step - loss: 0.5783 - accuracy: 0.8561 - val_loss: 2.2880 - val_accuracy: 0.5600
# Epoch 138/150
# 25/25 [==============================] - 402s 16s/step - loss: 0.5679 - accuracy: 0.8511 - val_loss: 2.2879 - val_accuracy: 0.5450
# Epoch 139/150
# 25/25 [==============================] - 403s 16s/step - loss: 0.5572 - accuracy: 0.8586 - val_loss: 2.2879 - val_accuracy: 0.5850
# Epoch 140/150
# 25/25 [==============================] - 410s 16s/step - loss: 0.5731 - accuracy: 0.8436 - val_loss: 2.2877 - val_accuracy: 0.5550
# Epoch 141/150
# 25/25 [==============================] - 402s 16s/step - loss: 0.5588 - accuracy: 0.8511 - val_loss: 2.2877 - val_accuracy: 0.5450
# Epoch 142/150
# 25/25 [==============================] - 404s 16s/step - loss: 0.5486 - accuracy: 0.8536 - val_loss: 2.2876 - val_accuracy: 0.5650
# Epoch 143/150
# 25/25 [==============================] - 401s 16s/step - loss: 0.5375 - accuracy: 0.8561 - val_loss: 2.2875 - val_accuracy: 0.5800
# Epoch 144/150
# 25/25 [==============================] - 404s 16s/step - loss: 0.5472 - accuracy: 0.8511 - val_loss: 2.2874 - val_accuracy: 0.5050
# Epoch 145/150
# 25/25 [==============================] - 404s 16s/step - loss: 0.5391 - accuracy: 0.8561 - val_loss: 2.2873 - val_accuracy: 0.5750
# Epoch 146/150
# 25/25 [==============================] - 404s 16s/step - loss: 0.5285 - accuracy: 0.8636 - val_loss: 2.2873 - val_accuracy: 0.5500
# Epoch 147/150
# 25/25 [==============================] - 400s 16s/step - loss: 0.5204 - accuracy: 0.8748 - val_loss: 2.2872 - val_accuracy: 0.5750
# Epoch 148/150
# 25/25 [==============================] - 402s 16s/step - loss: 0.5039 - accuracy: 0.8849 - val_loss: 2.2872 - val_accuracy: 0.5750
# Epoch 149/150
# 25/25 [==============================] - 409s 16s/step - loss: 0.5125 - accuracy: 0.8686 - val_loss: 2.2870 - val_accuracy: 0.5750
# Epoch 150/150
# 25/25 [==============================] - 403s 16s/step - loss: 0.4944 - accuracy: 0.8811 - val_loss: 2.2870 - val_accuracy: 0.5550

# %%
import matplotlib.pyplot as plt
#plt.plot(hist.history["accuracy"])

#plt.plot(hist.history['loss'])

#plt.title("model accuracy")
#plt.ylabel("Accuracy")
#plt.xlabel("Epoch")
#plt.legend(["Accuracy", "loss"])
#plt.show()

# %%
from keras.preprocessing import image
from keras.applications.vgg16 import decode_predictions
import tensorflow as tf
img = tf.keras.utils.load_img("C:/Users/alexa/Documents/Studium/Bachelor/Data2/testimages/hiphop/hiphop00005.png", target_size=(224,224))
img = np.asarray(img)
plt.imshow(img)
img = np.expand_dims(img, axis=0)
from keras.models import load_model
saved_model=load_model("vgg16_best_model_1.h5")
output = saved_model.predict(img)
print(output)
if ((output[0][0]>output[0][1]) and (output[0][0]>output[0][2]) and (output[0][0]>output[0][3]) and (output[0][0]>output[0][4]) and (output[0][0]>output[0][5]) and (output[0][0]>output[0][6]) and (output[0][0]>output[0][7]) and (output[0][0]>output[0][8]) and (output[0][0]>output[0][9])):
    print("Blues")
elif ((output[0][0]<output[0][1]) and (output[0][1]>output[0][2]) and (output[0][1]>output[0][3]) and (output[0][1]>output[0][4]) and (output[0][1]>output[0][5]) and (output[0][1]>output[0][6]) and (output[0][1]>output[0][7]) and (output[0][1]>output[0][8]) and (output[0][1]>output[0][9])):
    print("Classical")
elif((output[0][2]>output[0][0]) and (output[0][2]>output[0][1]) and (output[0][2]>output[0][3]) and (output[0][2]>output[0][4]) and (output[0][2]>output[0][5]) and (output[0][2]>output[0][6]) and (output[0][2]>output[0][7]) and (output[0][2]>output[0][8]) and (output[0][2]>output[0][9])):
    print("Country")
elif((output[0][3]>output[0][0]) and (output[0][3]>output[0][1]) and (output[0][3]>output[0][2]) and (output[0][3]>output[0][4]) and (output[0][3]>output[0][5]) and (output[0][3]>output[0][6]) and (output[0][3]>output[0][7]) and (output[0][3]>output[0][8]) and (output[0][3]>output[0][9])):
    print("Disco")
elif((output[0][4]>output[0][0]) and (output[0][4]>output[0][1]) and (output[0][4]>output[0][2]) and (output[0][4]>output[0][3]) and (output[0][4]>output[0][5]) and (output[0][4]>output[0][6]) and (output[0][4]>output[0][7]) and (output[0][4]>output[0][8]) and (output[0][4]>output[0][9])):
    print("Hiphop")
elif((output[0][5]>output[0][0]) and (output[0][5]>output[0][1]) and (output[0][5]>output[0][2]) and (output[0][5]>output[0][3]) and (output[0][5]>output[0][4]) and (output[0][5]>output[0][6]) and (output[0][5]>output[0][7]) and (output[0][5]>output[0][8]) and (output[0][5]>output[0][9])):
    print("Jazz")
elif((output[0][6]>output[0][0]) and (output[0][6]>output[0][1]) and (output[0][6]>output[0][2]) and (output[0][6]>output[0][3]) and (output[0][6]>output[0][4]) and (output[0][6]>output[0][5]) and (output[0][6]>output[0][7]) and (output[0][6]>output[0][8]) and (output[0][6]>output[0][9])):
    print("Metal")
elif((output[0][7]>output[0][0]) and (output[0][7]>output[0][1]) and (output[0][7]>output[0][2]) and (output[0][7]>output[0][3]) and (output[0][7]>output[0][4]) and (output[0][7]>output[0][5]) and (output[0][7]>output[0][6]) and (output[0][7]>output[0][8]) and (output[0][7]>output[0][9])):
    print("Pop")
elif((output[0][8]>output[0][0]) and (output[0][8]>output[0][1]) and (output[0][8]>output[0][2]) and (output[0][8]>output[0][3]) and (output[0][8]>output[0][4]) and (output[0][8]>output[0][5]) and (output[0][8]>output[0][6]) and (output[0][8]>output[0][7]) and (output[0][8]>output[0][9])):
    print("Reggae")
elif((output[0][9]>output[0][0]) and (output[0][9]>output[0][1]) and (output[0][9]>output[0][2]) and (output[0][9]>output[0][3]) and (output[0][9]>output[0][4]) and (output[0][9]>output[0][5]) and (output[0][9]>output[0][6]) and (output[0][9]>output[0][7]) and (output[0][9]>output[0][8])):
    print("Rock")
# Out:
# 1/1 [==============================] - 0s 281ms/step
# [[5.8438446e-02 8.8181798e-05 3.6528066e-02 2.0468135e-01 2.4804930e-01
#   2.0210797e-02 1.1944911e-01 8.7691046e-02 5.4908324e-02 1.6995540e-01]]
# Hiphop

# %%
import itertools

def plot_confusion_matrix(cm, classes, normalize=False,title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm=cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print("Confusion matrix, without normalization")
        
    plt.imshow(cm, interpolation='nearest',cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks=np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks,classes)
    
    fmt='.2f' if normalize else 'd'
    thresh = cm.max()/2
    for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j,i,format(cm[i,j],fmt),
                horizontalalignment="center",
                color="white" if cm[i,j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Confusion Matrix
saved_model=load_model("vgg16_best_model_1.h5")
Y_pred=saved_model.predict(test_data)
y_pred=np.argmax(Y_pred,axis=1)
print('Confusion Matrix')
cm=confusion_matrix(test_data.classes,y_pred)
genres={'blues':0, 'classical':1, 'country':2, 'disco':3, 'hiphop':4, 'jazz':5, 'metal':6, 'pop':7, 'reggae':8, 'rock':9}
keys = OrderedDict(sorted(genres.items(), key=lambda t: t[1])).keys()

plot_confusion_matrix(cm,keys,normalize=True)
plt.show()
# Out:
# 7/7 [==============================] - 19s 3s/step
# Confusion Matrix
# Normalized confusion matrix

# %%
def plot_loss_curves(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    
    epochs = range(len(history.history['loss']))
    
    plt.plot(epochs, loss, label='training_loss')
    plt.plot(epochs, val_loss, label='val_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()
    
    plt.figure()
    plt.plot(epochs, accuracy, label='training_accuracy')
    plt.plot(epochs, val_accuracy, label='val_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend();

# %%
plot_loss_curves(hist)

# %%
model.evaluate(testdata)
# Out:
# 7/7 [==============================] - 26s 4s/step - loss: 1.1721 - accuracy: 0.6100
# [1.1721099615097046, 0.6100000143051147]

# %%
#model2 = Sequential()
#model2.add(Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same",activation="relu"))
#model2.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
#model2.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model2.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
#model2.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
#model2.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model2.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
#model2.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
#model2.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
#model2.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model2.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model2.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model2.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model2.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model2.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model2.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model2.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model2.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model2.add(Flatten())
#model2.add(Dense(units=256, activation="relu"))
#model2.add(Dense(units=128, activation="relu"))
#model2.add(Dense(units=10, activation="softmax"))

# %%
#opt=Adam(learning_rate=1e-6)
#model2.compile(optimizer=opt, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
#model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 224, 224, 64)      1792
#
#  conv2d_14 (Conv2D)          (None, 224, 224, 64)      36928
#
#  max_pooling2d_5 (MaxPooling  (None, 112, 112, 64)     0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 112, 112, 128)     73856
#
#  conv2d_16 (Conv2D)          (None, 112, 112, 128)     147584
#
#  max_pooling2d_6 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_18 (Conv2D)          (None, 56, 56, 256)       590080
#
#  conv2d_19 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_7 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  max_pooling2d_8 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_9 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_3 (Dense)             (None, 256)               6422784
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 21,171,658
# Trainable params: 21,171,658
# Non-trainable params: 0
# _________________________________________________________________

# %%
#mc2=ModelCheckpoint("vgg16_best_model_2.h5", monitor='val_accuracy',mode='max',save_best_only=True)

#hist2=model2.fit(train_data_augmented, epochs=150, steps_per_epoch=len(train_data_augmented), validation_data=test_data, validation_steps=len(test_data), verbose=1,callbacks=[mc2])
# Out:
# Epoch 1/150
# 25/25 [==============================] - 363s 15s/step - loss: 2.3026 - accuracy: 0.1001 - val_loss: 2.3024 - val_accuracy: 0.1000
# Epoch 2/150
# 25/25 [==============================] - 378s 15s/step - loss: 2.3026 - accuracy: 0.1001 - val_loss: 2.3024 - val_accuracy: 0.1000
# Epoch 3/150
# 25/25 [==============================] - 376s 15s/step - loss: 2.3026 - accuracy: 0.1001 - val_loss: 2.3024 - val_accuracy: 0.1000
# Epoch 4/150
# 25/25 [==============================] - 378s 15s/step - loss: 2.3025 - accuracy: 0.1014 - val_loss: 2.3023 - val_accuracy: 0.1050
# Epoch 5/150
# 25/25 [==============================] - 379s 15s/step - loss: 2.3024 - accuracy: 0.1039 - val_loss: 2.3023 - val_accuracy: 0.1000
# Epoch 6/150
# 25/25 [==============================] - 374s 15s/step - loss: 2.3024 - accuracy: 0.0989 - val_loss: 2.3023 - val_accuracy: 0.1000
# Epoch 7/150
# 25/25 [==============================] - 377s 15s/step - loss: 2.3024 - accuracy: 0.1039 - val_loss: 2.3022 - val_accuracy: 0.1000
# Epoch 8/150
# 25/25 [==============================] - 370s 15s/step - loss: 2.3024 - accuracy: 0.1026 - val_loss: 2.3022 - val_accuracy: 0.1000
# Epoch 9/150
# 25/25 [==============================] - 371s 15s/step - loss: 2.3023 - accuracy: 0.1014 - val_loss: 2.3022 - val_accuracy: 0.1000
# Epoch 10/150
# 25/25 [==============================] - 376s 15s/step - loss: 2.3024 - accuracy: 0.0976 - val_loss: 2.3021 - val_accuracy: 0.1000
# Epoch 11/150
# 25/25 [==============================] - 363s 15s/step - loss: 2.3024 - accuracy: 0.1039 - val_loss: 2.3021 - val_accuracy: 0.1300
# Epoch 12/150
# 25/25 [==============================] - 360s 14s/step - loss: 2.3022 - accuracy: 0.1014 - val_loss: 2.3021 - val_accuracy: 0.1150
# Epoch 13/150
# 25/25 [==============================] - 359s 14s/step - loss: 2.3022 - accuracy: 0.1101 - val_loss: 2.3020 - val_accuracy: 0.1000
# Epoch 14/150
# 25/25 [==============================] - 358s 14s/step - loss: 2.3021 - accuracy: 0.1026 - val_loss: 2.3020 - val_accuracy: 0.1200
# Epoch 15/150
# 25/25 [==============================] - 357s 14s/step - loss: 2.3022 - accuracy: 0.1089 - val_loss: 2.3019 - val_accuracy: 0.1250
# Epoch 16/150
# 25/25 [==============================] - 360s 14s/step - loss: 2.3021 - accuracy: 0.1164 - val_loss: 2.3019 - val_accuracy: 0.1450
# Epoch 17/150
# 25/25 [==============================] - 362s 15s/step - loss: 2.3021 - accuracy: 0.1202 - val_loss: 2.3018 - val_accuracy: 0.1150
# Epoch 18/150
# 25/25 [==============================] - 362s 15s/step - loss: 2.3021 - accuracy: 0.0901 - val_loss: 2.3017 - val_accuracy: 0.1550
# Epoch 19/150
# 25/25 [==============================] - 359s 14s/step - loss: 2.3020 - accuracy: 0.1352 - val_loss: 2.3017 - val_accuracy: 0.1150
# Epoch 20/150
# 25/25 [==============================] - 356s 14s/step - loss: 2.3019 - accuracy: 0.1264 - val_loss: 2.3016 - val_accuracy: 0.1500
# Epoch 21/150
# 25/25 [==============================] - 354s 14s/step - loss: 2.3019 - accuracy: 0.0989 - val_loss: 2.3016 - val_accuracy: 0.1100
# Epoch 22/150
# 25/25 [==============================] - 367s 15s/step - loss: 2.3017 - accuracy: 0.1176 - val_loss: 2.3014 - val_accuracy: 0.1300
# Epoch 23/150
# 25/25 [==============================] - 375s 15s/step - loss: 2.3017 - accuracy: 0.1101 - val_loss: 2.3014 - val_accuracy: 0.1300
# Epoch 24/150
# 25/25 [==============================] - 379s 15s/step - loss: 2.3017 - accuracy: 0.1101 - val_loss: 2.3013 - val_accuracy: 0.1250
# Epoch 25/150
# 25/25 [==============================] - 398s 16s/step - loss: 2.3016 - accuracy: 0.1264 - val_loss: 2.3012 - val_accuracy: 0.1750
# Epoch 26/150
# 25/25 [==============================] - 393s 16s/step - loss: 2.3015 - accuracy: 0.1552 - val_loss: 2.3010 - val_accuracy: 0.1250
# Epoch 27/150
# 25/25 [==============================] - 386s 15s/step - loss: 2.3014 - accuracy: 0.1364 - val_loss: 2.3009 - val_accuracy: 0.1550
# Epoch 28/150
# 25/25 [==============================] - 378s 15s/step - loss: 2.3013 - accuracy: 0.1289 - val_loss: 2.3008 - val_accuracy: 0.1250
# Epoch 29/150
# 25/25 [==============================] - 377s 15s/step - loss: 2.3011 - accuracy: 0.1314 - val_loss: 2.3006 - val_accuracy: 0.1300
# Epoch 30/150
# 25/25 [==============================] - 387s 16s/step - loss: 2.3011 - accuracy: 0.1189 - val_loss: 2.3004 - val_accuracy: 0.1800
# Epoch 31/150
# 25/25 [==============================] - 392s 16s/step - loss: 2.3007 - accuracy: 0.1539 - val_loss: 2.3002 - val_accuracy: 0.1350
# Epoch 32/150
# 25/25 [==============================] - 391s 16s/step - loss: 2.3007 - accuracy: 0.1414 - val_loss: 2.3000 - val_accuracy: 0.1750
# Epoch 33/150
# 25/25 [==============================] - 375s 15s/step - loss: 2.3005 - accuracy: 0.1527 - val_loss: 2.2998 - val_accuracy: 0.1450
# Epoch 34/150
# 25/25 [==============================] - 380s 15s/step - loss: 2.3002 - accuracy: 0.1514 - val_loss: 2.2994 - val_accuracy: 0.1950
# Epoch 35/150
# 25/25 [==============================] - 380s 15s/step - loss: 2.2999 - accuracy: 0.1602 - val_loss: 2.2991 - val_accuracy: 0.1700
# Epoch 36/150
# 25/25 [==============================] - 387s 16s/step - loss: 2.2997 - accuracy: 0.1427 - val_loss: 2.2987 - val_accuracy: 0.1700
# Epoch 37/150
# 25/25 [==============================] - 385s 15s/step - loss: 2.2997 - accuracy: 0.1452 - val_loss: 2.2983 - val_accuracy: 0.1750
# Epoch 38/150
# 25/25 [==============================] - 387s 16s/step - loss: 2.2989 - accuracy: 0.1765 - val_loss: 2.2978 - val_accuracy: 0.1800
# Epoch 39/150
# 25/25 [==============================] - 390s 16s/step - loss: 2.2988 - accuracy: 0.1815 - val_loss: 2.2972 - val_accuracy: 0.2050
# Epoch 40/150
# 25/25 [==============================] - 389s 16s/step - loss: 2.2983 - accuracy: 0.1564 - val_loss: 2.2967 - val_accuracy: 0.2450
# Epoch 41/150
# 25/25 [==============================] - 399s 16s/step - loss: 2.2978 - accuracy: 0.1352 - val_loss: 2.2960 - val_accuracy: 0.1850
# Epoch 42/150
# 25/25 [==============================] - 395s 16s/step - loss: 2.2974 - accuracy: 0.1740 - val_loss: 2.2954 - val_accuracy: 0.2400
# Epoch 43/150
# 25/25 [==============================] - 394s 16s/step - loss: 2.2966 - accuracy: 0.1952 - val_loss: 2.2944 - val_accuracy: 0.2250
# Epoch 44/150
# 25/25 [==============================] - 397s 16s/step - loss: 2.2959 - accuracy: 0.1552 - val_loss: 2.2933 - val_accuracy: 0.2050
# Epoch 45/150
# 25/25 [==============================] - 401s 16s/step - loss: 2.2950 - accuracy: 0.1740 - val_loss: 2.2923 - val_accuracy: 0.2300
# Epoch 46/150
# 25/25 [==============================] - 397s 16s/step - loss: 2.2944 - accuracy: 0.1552 - val_loss: 2.2912 - val_accuracy: 0.1800
# Epoch 47/150
# 25/25 [==============================] - 394s 16s/step - loss: 2.2933 - accuracy: 0.1990 - val_loss: 2.2898 - val_accuracy: 0.2450
# Epoch 48/150
# 25/25 [==============================] - 411s 16s/step - loss: 2.2921 - accuracy: 0.2003 - val_loss: 2.2877 - val_accuracy: 0.2000
# Epoch 49/150
# 25/25 [==============================] - 394s 16s/step - loss: 2.2895 - accuracy: 0.1927 - val_loss: 2.2858 - val_accuracy: 0.2300
# Epoch 50/150
# 25/25 [==============================] - 417s 17s/step - loss: 2.2892 - accuracy: 0.1977 - val_loss: 2.2838 - val_accuracy: 0.2450
# Epoch 51/150
# 25/25 [==============================] - 428s 17s/step - loss: 2.2858 - accuracy: 0.1902 - val_loss: 2.2812 - val_accuracy: 0.2100
# Epoch 52/150
# 25/25 [==============================] - 417s 17s/step - loss: 2.2844 - accuracy: 0.1877 - val_loss: 2.2781 - val_accuracy: 0.2250
# Epoch 53/150
# 25/25 [==============================] - 401s 16s/step - loss: 2.2862 - accuracy: 0.1489 - val_loss: 2.2758 - val_accuracy: 0.2250
# Epoch 54/150
# 25/25 [==============================] - 401s 16s/step - loss: 2.2818 - accuracy: 0.2078 - val_loss: 2.2743 - val_accuracy: 0.2400
# Epoch 55/150
# 25/25 [==============================] - 403s 16s/step - loss: 2.2768 - accuracy: 0.2053 - val_loss: 2.2681 - val_accuracy: 0.2350
# Epoch 56/150
# 25/25 [==============================] - 390s 16s/step - loss: 2.2750 - accuracy: 0.1652 - val_loss: 2.2652 - val_accuracy: 0.2000
# Epoch 57/150
# 25/25 [==============================] - 392s 16s/step - loss: 2.2685 - accuracy: 0.1915 - val_loss: 2.2589 - val_accuracy: 0.2250
# Epoch 58/150
# 25/25 [==============================] - 395s 16s/step - loss: 2.2637 - accuracy: 0.2215 - val_loss: 2.2527 - val_accuracy: 0.2350
# Epoch 59/150
# 25/25 [==============================] - 402s 16s/step - loss: 2.2617 - accuracy: 0.1727 - val_loss: 2.2463 - val_accuracy: 0.2200
# Epoch 60/150
# 25/25 [==============================] - 403s 16s/step - loss: 2.2555 - accuracy: 0.2028 - val_loss: 2.2391 - val_accuracy: 0.2250
# Epoch 61/150
# 25/25 [==============================] - 400s 16s/step - loss: 2.2475 - accuracy: 0.1927 - val_loss: 2.2312 - val_accuracy: 0.2200
# Epoch 62/150
# 25/25 [==============================] - 397s 16s/step - loss: 2.2421 - accuracy: 0.1990 - val_loss: 2.2238 - val_accuracy: 0.2250
# Epoch 63/150
# 25/25 [==============================] - 395s 16s/step - loss: 2.2381 - accuracy: 0.1915 - val_loss: 2.2143 - val_accuracy: 0.2200
# Epoch 64/150
# 25/25 [==============================] - 391s 16s/step - loss: 2.2303 - accuracy: 0.1802 - val_loss: 2.2049 - val_accuracy: 0.2250
# Epoch 65/150
# 25/25 [==============================] - 387s 16s/step - loss: 2.2148 - accuracy: 0.1890 - val_loss: 2.1950 - val_accuracy: 0.2150
# Epoch 66/150
# 25/25 [==============================] - 399s 16s/step - loss: 2.2177 - accuracy: 0.1815 - val_loss: 2.1836 - val_accuracy: 0.2350
# Epoch 67/150
# 25/25 [==============================] - 400s 16s/step - loss: 2.2061 - accuracy: 0.1815 - val_loss: 2.1761 - val_accuracy: 0.2200
# Epoch 68/150
# 25/25 [==============================] - 401s 16s/step - loss: 2.1999 - accuracy: 0.1927 - val_loss: 2.1657 - val_accuracy: 0.2300
# Epoch 69/150
# 25/25 [==============================] - 419s 17s/step - loss: 2.1832 - accuracy: 0.2015 - val_loss: 2.1551 - val_accuracy: 0.2150
# Epoch 70/150
# 25/25 [==============================] - 378s 15s/step - loss: 2.1780 - accuracy: 0.1902 - val_loss: 2.1462 - val_accuracy: 0.2450
# Epoch 71/150
# 25/25 [==============================] - 384s 15s/step - loss: 2.1723 - accuracy: 0.1865 - val_loss: 2.1374 - val_accuracy: 0.2200
# Epoch 72/150
# 25/25 [==============================] - 384s 15s/step - loss: 2.1627 - accuracy: 0.1990 - val_loss: 2.1346 - val_accuracy: 0.2100
# Epoch 73/150
# 25/25 [==============================] - 374s 15s/step - loss: 2.1548 - accuracy: 0.1740 - val_loss: 2.1260 - val_accuracy: 0.2100
# Epoch 74/150
# 25/25 [==============================] - 383s 15s/step - loss: 2.1556 - accuracy: 0.1915 - val_loss: 2.1152 - val_accuracy: 0.2150
# Epoch 75/150
# 25/25 [==============================] - 411s 16s/step - loss: 2.1314 - accuracy: 0.2003 - val_loss: 2.1046 - val_accuracy: 0.2050
# Epoch 76/150
# 25/25 [==============================] - 398s 16s/step - loss: 2.1372 - accuracy: 0.1940 - val_loss: 2.0982 - val_accuracy: 0.2200
# Epoch 77/150
# 25/25 [==============================] - 390s 16s/step - loss: 2.1180 - accuracy: 0.1840 - val_loss: 2.0930 - val_accuracy: 0.2200
# Epoch 78/150
# 25/25 [==============================] - 392s 16s/step - loss: 2.1091 - accuracy: 0.2115 - val_loss: 2.0830 - val_accuracy: 0.2300
# Epoch 79/150
# 25/25 [==============================] - 401s 16s/step - loss: 2.1045 - accuracy: 0.1952 - val_loss: 2.0765 - val_accuracy: 0.2350
# Epoch 80/150
# 25/25 [==============================] - 394s 16s/step - loss: 2.1049 - accuracy: 0.1890 - val_loss: 2.0742 - val_accuracy: 0.2100
# Epoch 81/150
# 25/25 [==============================] - 390s 16s/step - loss: 2.0932 - accuracy: 0.2078 - val_loss: 2.0666 - val_accuracy: 0.2200
# Epoch 82/150
# 25/25 [==============================] - 393s 16s/step - loss: 2.1084 - accuracy: 0.1952 - val_loss: 2.0635 - val_accuracy: 0.2250
# Epoch 83/150
# 25/25 [==============================] - 388s 16s/step - loss: 2.0917 - accuracy: 0.2065 - val_loss: 2.0601 - val_accuracy: 0.2200
# Epoch 84/150
# 25/25 [==============================] - 400s 16s/step - loss: 2.1128 - accuracy: 0.1977 - val_loss: 2.0550 - val_accuracy: 0.2700
# Epoch 85/150
# 25/25 [==============================] - 393s 16s/step - loss: 2.0754 - accuracy: 0.2203 - val_loss: 2.0506 - val_accuracy: 0.2300
# Epoch 86/150
# 25/25 [==============================] - 397s 16s/step - loss: 2.0788 - accuracy: 0.2015 - val_loss: 2.0534 - val_accuracy: 0.2250
# Epoch 87/150
# 25/25 [==============================] - 399s 16s/step - loss: 2.0767 - accuracy: 0.2178 - val_loss: 2.0422 - val_accuracy: 0.2700
# Epoch 88/150
# 25/25 [==============================] - 399s 16s/step - loss: 2.0600 - accuracy: 0.2278 - val_loss: 2.0416 - val_accuracy: 0.2450
# Epoch 89/150
# 25/25 [==============================] - 397s 16s/step - loss: 2.0722 - accuracy: 0.2365 - val_loss: 2.0363 - val_accuracy: 0.2650
# Epoch 90/150
# 25/25 [==============================] - 373s 15s/step - loss: 2.0529 - accuracy: 0.2516 - val_loss: 2.0486 - val_accuracy: 0.2500
# Epoch 91/150
# 25/25 [==============================] - 382s 15s/step - loss: 2.0616 - accuracy: 0.2378 - val_loss: 2.0321 - val_accuracy: 0.2600
# Epoch 92/150
# 25/25 [==============================] - 386s 15s/step - loss: 2.0634 - accuracy: 0.2128 - val_loss: 2.0272 - val_accuracy: 0.2700
# Epoch 93/150
# 25/25 [==============================] - 397s 16s/step - loss: 2.0473 - accuracy: 0.2240 - val_loss: 2.0345 - val_accuracy: 0.2450
# Epoch 94/150
# 25/25 [==============================] - 391s 16s/step - loss: 2.0557 - accuracy: 0.2466 - val_loss: 2.0345 - val_accuracy: 0.2700
# Epoch 95/150
# 25/25 [==============================] - 390s 16s/step - loss: 2.0385 - accuracy: 0.2641 - val_loss: 2.0241 - val_accuracy: 0.2600
# Epoch 96/150
# 25/25 [==============================] - 393s 16s/step - loss: 2.0565 - accuracy: 0.2403 - val_loss: 2.0178 - val_accuracy: 0.2750
# Epoch 97/150
# 25/25 [==============================] - 391s 16s/step - loss: 2.0440 - accuracy: 0.2390 - val_loss: 2.0165 - val_accuracy: 0.2800
# Epoch 98/150
# 25/25 [==============================] - 407s 16s/step - loss: 2.0356 - accuracy: 0.2503 - val_loss: 2.0162 - val_accuracy: 0.3050
# Epoch 99/150
# 25/25 [==============================] - 406s 16s/step - loss: 2.0281 - accuracy: 0.2503 - val_loss: 2.0142 - val_accuracy: 0.2750
# Epoch 100/150
# 25/25 [==============================] - 404s 16s/step - loss: 2.0258 - accuracy: 0.2678 - val_loss: 2.0176 - val_accuracy: 0.2950
# Epoch 101/150
# 25/25 [==============================] - 400s 16s/step - loss: 2.0258 - accuracy: 0.2416 - val_loss: 2.0077 - val_accuracy: 0.2900
# Epoch 102/150
# 25/25 [==============================] - 403s 16s/step - loss: 2.0248 - accuracy: 0.2528 - val_loss: 2.0040 - val_accuracy: 0.3100
# Epoch 103/150
# 25/25 [==============================] - 400s 16s/step - loss: 2.0373 - accuracy: 0.2741 - val_loss: 2.0021 - val_accuracy: 0.3150
# Epoch 104/150
# 25/25 [==============================] - 393s 16s/step - loss: 2.0371 - accuracy: 0.2553 - val_loss: 2.0026 - val_accuracy: 0.2900
# Epoch 105/150
# 25/25 [==============================] - 397s 16s/step - loss: 2.0290 - accuracy: 0.2466 - val_loss: 2.0092 - val_accuracy: 0.2900
# Epoch 106/150
# 25/25 [==============================] - 395s 16s/step - loss: 2.0202 - accuracy: 0.2503 - val_loss: 1.9989 - val_accuracy: 0.2950
# Epoch 107/150
# 25/25 [==============================] - 394s 16s/step - loss: 2.0126 - accuracy: 0.2766 - val_loss: 2.0005 - val_accuracy: 0.3000
# Epoch 108/150
# 25/25 [==============================] - 392s 16s/step - loss: 2.0125 - accuracy: 0.2478 - val_loss: 1.9975 - val_accuracy: 0.2700
# Epoch 109/150
# 25/25 [==============================] - 397s 16s/step - loss: 2.0066 - accuracy: 0.2941 - val_loss: 2.0107 - val_accuracy: 0.2750
# Epoch 110/150
# 25/25 [==============================] - 395s 16s/step - loss: 2.0037 - accuracy: 0.2916 - val_loss: 2.0062 - val_accuracy: 0.2900
# Epoch 111/150
# 25/25 [==============================] - 393s 16s/step - loss: 1.9995 - accuracy: 0.2829 - val_loss: 1.9955 - val_accuracy: 0.2950
# Epoch 112/150
# 25/25 [==============================] - 396s 16s/step - loss: 2.0101 - accuracy: 0.2315 - val_loss: 1.9932 - val_accuracy: 0.2700
# Epoch 113/150
# 25/25 [==============================] - 396s 16s/step - loss: 1.9994 - accuracy: 0.2666 - val_loss: 1.9914 - val_accuracy: 0.3100
# Epoch 114/150
# 25/25 [==============================] - 396s 16s/step - loss: 1.9956 - accuracy: 0.2879 - val_loss: 1.9887 - val_accuracy: 0.2800
# Epoch 115/150
# 25/25 [==============================] - 392s 16s/step - loss: 1.9931 - accuracy: 0.2691 - val_loss: 1.9895 - val_accuracy: 0.2800
# Epoch 116/150
# 25/25 [==============================] - 398s 16s/step - loss: 2.0028 - accuracy: 0.2678 - val_loss: 1.9851 - val_accuracy: 0.3250
# Epoch 117/150
# 25/25 [==============================] - 389s 16s/step - loss: 2.0033 - accuracy: 0.2691 - val_loss: 1.9975 - val_accuracy: 0.2650
# Epoch 118/150
# 25/25 [==============================] - 394s 16s/step - loss: 1.9856 - accuracy: 0.2829 - val_loss: 1.9867 - val_accuracy: 0.2800
# Epoch 119/150
# 25/25 [==============================] - 395s 16s/step - loss: 1.9806 - accuracy: 0.2854 - val_loss: 1.9764 - val_accuracy: 0.3050
# Epoch 120/150
# 25/25 [==============================] - 397s 16s/step - loss: 1.9943 - accuracy: 0.2879 - val_loss: 1.9783 - val_accuracy: 0.2800
# Epoch 121/150
# 25/25 [==============================] - 390s 16s/step - loss: 2.0023 - accuracy: 0.2678 - val_loss: 1.9755 - val_accuracy: 0.2700
# Epoch 122/150
# 25/25 [==============================] - 392s 16s/step - loss: 2.0044 - accuracy: 0.2766 - val_loss: 1.9965 - val_accuracy: 0.2700
# Epoch 123/150
# 25/25 [==============================] - 398s 16s/step - loss: 1.9773 - accuracy: 0.2791 - val_loss: 1.9724 - val_accuracy: 0.2900
# Epoch 124/150
# 25/25 [==============================] - 392s 16s/step - loss: 1.9809 - accuracy: 0.2653 - val_loss: 1.9846 - val_accuracy: 0.2450
# Epoch 125/150
# 25/25 [==============================] - 392s 16s/step - loss: 1.9870 - accuracy: 0.3041 - val_loss: 1.9740 - val_accuracy: 0.2950
# Epoch 126/150
# 25/25 [==============================] - 393s 16s/step - loss: 1.9938 - accuracy: 0.2804 - val_loss: 1.9746 - val_accuracy: 0.2750
# Epoch 127/150
# 25/25 [==============================] - 397s 16s/step - loss: 1.9795 - accuracy: 0.2841 - val_loss: 1.9671 - val_accuracy: 0.2700
# Epoch 128/150
# 25/25 [==============================] - 397s 16s/step - loss: 1.9799 - accuracy: 0.2879 - val_loss: 1.9739 - val_accuracy: 0.2900
# Epoch 129/150
# 25/25 [==============================] - 406s 16s/step - loss: 1.9691 - accuracy: 0.2979 - val_loss: 1.9636 - val_accuracy: 0.3000
# Epoch 130/150
# 25/25 [==============================] - 400s 16s/step - loss: 1.9713 - accuracy: 0.2816 - val_loss: 1.9682 - val_accuracy: 0.2700
# Epoch 131/150
# 25/25 [==============================] - 399s 16s/step - loss: 1.9729 - accuracy: 0.2916 - val_loss: 1.9738 - val_accuracy: 0.2600
# Epoch 132/150
# 25/25 [==============================] - 403s 16s/step - loss: 1.9783 - accuracy: 0.2954 - val_loss: 1.9660 - val_accuracy: 0.3050
# Epoch 133/150
# 25/25 [==============================] - 401s 16s/step - loss: 1.9862 - accuracy: 0.3166 - val_loss: 1.9609 - val_accuracy: 0.2950
# Epoch 134/150
# 25/25 [==============================] - 404s 16s/step - loss: 1.9709 - accuracy: 0.2929 - val_loss: 1.9703 - val_accuracy: 0.2750
# Epoch 135/150
# 25/25 [==============================] - 402s 16s/step - loss: 1.9823 - accuracy: 0.2603 - val_loss: 1.9683 - val_accuracy: 0.2600
# Epoch 136/150
# 25/25 [==============================] - 402s 16s/step - loss: 1.9536 - accuracy: 0.2904 - val_loss: 1.9756 - val_accuracy: 0.2850
# Epoch 137/150
# 25/25 [==============================] - 400s 16s/step - loss: 1.9682 - accuracy: 0.2841 - val_loss: 1.9553 - val_accuracy: 0.3200
# Epoch 138/150
# 25/25 [==============================] - 402s 16s/step - loss: 1.9714 - accuracy: 0.2916 - val_loss: 1.9581 - val_accuracy: 0.3100
# Epoch 139/150
# 25/25 [==============================] - 435s 18s/step - loss: 1.9639 - accuracy: 0.2904 - val_loss: 1.9623 - val_accuracy: 0.2950
# Epoch 140/150
# 25/25 [==============================] - 433s 17s/step - loss: 1.9649 - accuracy: 0.3029 - val_loss: 1.9585 - val_accuracy: 0.3000
# Epoch 141/150
# 25/25 [==============================] - 427s 17s/step - loss: 1.9427 - accuracy: 0.3204 - val_loss: 1.9501 - val_accuracy: 0.2950
# Epoch 142/150
# 25/25 [==============================] - 413s 17s/step - loss: 1.9616 - accuracy: 0.2879 - val_loss: 1.9565 - val_accuracy: 0.2900
# Epoch 143/150
# 25/25 [==============================] - 407s 16s/step - loss: 1.9590 - accuracy: 0.3204 - val_loss: 1.9582 - val_accuracy: 0.2850
# Epoch 144/150
# 25/25 [==============================] - 408s 16s/step - loss: 1.9396 - accuracy: 0.3242 - val_loss: 1.9533 - val_accuracy: 0.3000
# Epoch 145/150
# 25/25 [==============================] - 404s 16s/step - loss: 1.9430 - accuracy: 0.3016 - val_loss: 1.9514 - val_accuracy: 0.2800
# Epoch 146/150
# 25/25 [==============================] - 403s 16s/step - loss: 1.9742 - accuracy: 0.3041 - val_loss: 1.9476 - val_accuracy: 0.2950
# Epoch 147/150
# 25/25 [==============================] - 406s 16s/step - loss: 1.9450 - accuracy: 0.2979 - val_loss: 1.9504 - val_accuracy: 0.2700
# Epoch 148/150
# 25/25 [==============================] - 403s 16s/step - loss: 1.9378 - accuracy: 0.2841 - val_loss: 1.9470 - val_accuracy: 0.3200
# Epoch 149/150
# 25/25 [==============================] - 402s 16s/step - loss: 1.9535 - accuracy: 0.3004 - val_loss: 1.9419 - val_accuracy: 0.3500
# Epoch 150/150
# 25/25 [==============================] - 403s 16s/step - loss: 1.9585 - accuracy: 0.2804 - val_loss: 1.9597 - val_accuracy: 0.2700

# %%
#plot_loss_curves(hist2)

# %%
#model2.evaluate(test_data)
# Out:
# 7/7 [==============================] - 25s 3s/step - loss: 1.9597 - accuracy: 0.2700
# [1.9597156047821045, 0.27000001072883606]

# %%
#model3 = Sequential()
#model3.add(Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same",activation="relu"))
#model3.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
#model3.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model3.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
#model3.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
#model3.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model3.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
#model3.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
#model3.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
#model3.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model3.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model3.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model3.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model3.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model3.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model3.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model3.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model3.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model3.add(Flatten())
#model3.add(Dense(units=4096, activation="relu"))
#model3.add(Dropout(0.2))
#model3.add(Dense(units=4096, activation="relu"))
#model3.add(Dropout(0.2))
#model3.add(Dense(units=10, activation="softmax"))

# %%
#opt3=Adam(learning_rate=1e-8)
#model3.compile(optimizer=opt3, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
#model3.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_91 (Conv2D)          (None, 224, 224, 64)      1792
#
#  conv2d_92 (Conv2D)          (None, 224, 224, 64)      36928
#
#  max_pooling2d_35 (MaxPoolin  (None, 112, 112, 64)     0
#  g2D)
#
#  conv2d_93 (Conv2D)          (None, 112, 112, 128)     73856
#
#  conv2d_94 (Conv2D)          (None, 112, 112, 128)     147584
#
#  max_pooling2d_36 (MaxPoolin  (None, 56, 56, 128)      0
#  g2D)
#
#  conv2d_95 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_96 (Conv2D)          (None, 56, 56, 256)       590080
#
#  conv2d_97 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_37 (MaxPoolin  (None, 28, 28, 256)      0
#  g2D)
#
#  conv2d_98 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  conv2d_99 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  conv2d_100 (Conv2D)         (None, 28, 28, 512)       2359808
#
#  max_pooling2d_38 (MaxPoolin  (None, 14, 14, 512)      0
#  g2D)
#
#  conv2d_101 (Conv2D)         (None, 14, 14, 512)       2359808
#
#  conv2d_102 (Conv2D)         (None, 14, 14, 512)       2359808
#
#  conv2d_103 (Conv2D)         (None, 14, 14, 512)       2359808
#
#  max_pooling2d_39 (MaxPoolin  (None, 7, 7, 512)        0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 25088)             0
#
#  dense_19 (Dense)            (None, 4096)              102764544
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_20 (Dense)            (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_21 (Dense)            (None, 10)                40970
#
# =================================================================
# Total params: 134,301,514
# Trainable params: 134,301,514
# Non-trainable params: 0
# _________________________________________________________________

# %%
# augumented data
#train_datagen_augmented2 = ImageDataGenerator(rescale=1/255.,
                                            shear_range=0.2,
                                            zoom_range=0.2,
                                            width_shift_range=0.2,
                                            height_shift_range=0.2,
                                            rotation_range=20,
                                            horizontal_flip=True)
#test_datagen2 = ImageDataGenerator(rescale=1/255.)



# Load data
#train_data_augmented2 = train_datagen_augmented2.flow_from_directory(train_dir,
                                              target_size=(224,224),
                                              batch_size=32,
                                              class_mode='categorical',
                                              shuffle = False)
#test_data2 = test_datagen2.flow_from_directory(test_dir,
                                            target_size=(224,224),
                                            batch_size=32,
                                            class_mode='categorical',
                                            shuffle = False)

#mc3=ModelCheckpoint("vgg16_best_model_3.h5", monitor='val_accuracy',mode='max',save_best_only=True)

#hist3=model3.fit(train_data_augmented2, epochs=300, steps_per_epoch=len(train_data_augmented2), validation_data=test_data2, validation_steps=len(test_data2), verbose=1,callbacks=[mc3])
# Out:
# Found 799 images belonging to 10 classes.
# Found 200 images belonging to 10 classes.
# Epoch 1/300
# 25/25 [==============================] - 407s 16s/step - loss: 2.3026 - accuracy: 0.0901 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/300
# 25/25 [==============================] - 407s 16s/step - loss: 2.3026 - accuracy: 0.1026 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/300
# 25/25 [==============================] - 413s 17s/step - loss: 2.3026 - accuracy: 0.0876 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 4/300
# 25/25 [==============================] - 411s 16s/step - loss: 2.3026 - accuracy: 0.0939 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 5/300
# 25/25 [==============================] - 412s 16s/step - loss: 2.3026 - accuracy: 0.1064 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 6/300
# 25/25 [==============================] - 415s 17s/step - loss: 2.3026 - accuracy: 0.1076 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 7/300
# 25/25 [==============================] - 415s 17s/step - loss: 2.3025 - accuracy: 0.1051 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 8/300
# 25/25 [==============================] - 410s 16s/step - loss: 2.3026 - accuracy: 0.0976 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 9/300
# 25/25 [==============================] - 409s 16s/step - loss: 2.3026 - accuracy: 0.1039 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 10/300
# 25/25 [==============================] - 408s 16s/step - loss: 2.3026 - accuracy: 0.1076 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 11/300
# 25/25 [==============================] - 415s 17s/step - loss: 2.3026 - accuracy: 0.1001 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 12/300
# 25/25 [==============================] - 409s 16s/step - loss: 2.3026 - accuracy: 0.0989 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 13/300
# 25/25 [==============================] - 412s 17s/step - loss: 2.3026 - accuracy: 0.1014 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 14/300
# 15/25 [=================>............] - ETA: 2:38 - loss: 2.3027 - accuracy: 0.0708
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_52752\3595933054.py in <module>
#      25 mc3=ModelCheckpoint("vgg16_best_model_3.h5", monitor='val_accuracy',mode='max',save_best_only=True)
#      26
# ---> 27 hist3=model3.fit(train_data_augmented2, epochs=300, steps_per_epoch=len(train_data_augmented2), validation_data=test_data2, validation_steps=len(test_data2), verbose=1,callbacks=[mc3])
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
#plot_loss_curves(hist3)

# %%
#model3.evaluate(test_data)

# %%
#traindata2 = train_datagen.flow_from_directory(directory="C:/Users/alexa/Documents/Studium/Bachelor/Data2/trainimages/",target_size=(224,224), batch_size=32, class_mode='categorical', shuffle=False)

#testdata2 = test_datagen.flow_from_directory(directory="C:/Users/alexa/Documents/Studium/Bachelor/Data2/testimages/", target_size=(224,224), batch_size=32, class_mode='categorical', shuffle=False)
# Out:
# Found 799 images belonging to 10 classes.
# Found 200 images belonging to 10 classes.

# %%
#model4 = Sequential()
#model4.add(Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same",activation="relu"))
#model4.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
#model4.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model4.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
#model4.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
#model4.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model4.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
#model4.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
#model4.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
#model4.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model4.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model4.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model4.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model4.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model4.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model4.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model4.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
#model4.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
#model4.add(Flatten())
#model4.add(Dense(units=256, activation="relu"))
#model4.add(Dense(units=128, activation="relu"))

#model4.add(Dense(units=10, activation="softmax"))

# %%
#opt4=Adam(learning_rate=0.01)
#model4.compile(optimizer=opt4, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
#model4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 64)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 21,171,658
# Trainable params: 21,171,658
# Non-trainable params: 0
# _________________________________________________________________

# %%
#mc4=ModelCheckpoint("vgg16_best_model_4.h5", monitor='val_accuracy',mode='max',save_best_only=True)

#hist4=model4.fit(train_data_augmented, epochs=300, steps_per_epoch=len(train_data_augmented), validation_data=test_data, validation_steps=len(test_data), verbose=1,callbacks=[mc4])
# Out:
# Epoch 1/300
# 50/50 [==============================] - 387s 8s/step - loss: 17627738112.0000 - accuracy: 0.1101 - val_loss: 2.3043 - val_accuracy: 0.1000
# Epoch 2/300
# 50/50 [==============================] - 405s 8s/step - loss: 4.6561 - accuracy: 0.0388 - val_loss: 2.3045 - val_accuracy: 0.1000
# Epoch 3/300
# 50/50 [==============================] - 411s 8s/step - loss: 2.3188 - accuracy: 0.0601 - val_loss: 2.3035 - val_accuracy: 0.1000
# Epoch 4/300
# 50/50 [==============================] - 417s 8s/step - loss: 2.3156 - accuracy: 0.0401 - val_loss: 2.3035 - val_accuracy: 0.1000
# Epoch 5/300
# 50/50 [==============================] - 415s 8s/step - loss: 2.3125 - accuracy: 0.0413 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 6/300
# 50/50 [==============================] - 412s 8s/step - loss: 2.3116 - accuracy: 0.0200 - val_loss: 2.3034 - val_accuracy: 0.1000
# Epoch 7/300
# 50/50 [==============================] - 392s 8s/step - loss: 2.3150 - accuracy: 0.0601 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch
- val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 40/300
# 50/50 [==============================] - 394s 8s/step - loss: 2.3122 - accuracy: 0.0413 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 41/300
# 50/50 [==============================] - 412s 8s/step - loss: 2.3128 - accuracy: 0.0000e+00 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 42/300
# 50/50 [==============================] - 397s 8s/step - loss: 2.3131 - accuracy: 0.0426 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 43/300
# 50/50 [==============================] - 398s 8s/step - loss: 2.3145 - accuracy: 0.0200 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 44/300
# 50/50 [==============================] - 396s 8s/step - loss: 2.3104 - accuracy: 0.0601 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 45/300
# 50/50 [==============================] - 394s 8s/step - loss: 2.3124 - accuracy: 0.0401 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 46/300
# 50/50 [==============================] - 398s 8s/step - loss: 2.3125 - accuracy: 0.0413 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 47/300
# 50/50 [==============================] - 394s 8s/step - loss: 2.3149 - accuracy: 0.0401 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 48/300
# 50/50 [==============================] - 402s 8s/step - loss: 2.3144 - accuracy: 0.0401 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 49/300
# 50/50 [==============================] - 403s 8s/step - loss: 2.3138 - accuracy: 0.0401 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 50/300
# 50/50 [==============================] - 403s 8s/step - loss: 2.3139 - accuracy: 0.0200 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 51/300
# 50/50 [==============================] - 404s 8s/step - loss: 2.3134 - accuracy: 0.0601 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 52/300
# 50/50 [==============================] - 399s 8s/step - loss: 2.3151 - accuracy: 0.0213 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 53/300
# 50/50 [==============================] - 422s 8s/step - loss: 2.3142 - accuracy: 0.0388 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 54/300
# 50/50 [==============================] - 426s 9s/step - loss: 2.3094 - accuracy: 0.0788 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 55/300
# 50/50 [==============================] - 400s 8s/step - loss: 2.3118 - accuracy: 0.0413 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 56/300
#  7/50 [===>..........................] - ETA: 5:52 - loss: 2.3063 - accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_149236\756006126.py in <module>
#       1 mc4=ModelCheckpoint("vgg16_best_model_4.h5", monitor='val_accuracy',mode='max',save_best_only=True)
#       2
# ----> 3 hist4=model4.fit(train_data_augmented, epochs=300, steps_per_epoch=len(train_data_augmented), validation_data=test_data, validation_steps=len(test_data), verbose=1,callbacks=[mc4])
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ## References

# %% [markdown]
# Source: Great Learning & Rohini G. (2021, September 23). Everything you need to know about VGG16 - Great Learning - Medium. Medium. Retrieved April 14, 2023, from https://medium.com/@mygreatlearning/everything-you-need-to-know-about-vgg16-7315defb5918

# %% [markdown]
# Source: Bourke, D. (2020). 03. Convolutional Neural Networks and Computer Vision with TensorFlow: Multi-class Classification. Zero to Mastery TensorFlow for Deep Learning. Retrieved April 14, 2023, from https://dev.mrdbourke.com/tensorflow-deep-learning/03_convolutional_neural_networks_in_tensorflow/#multi-class-classification

# %% [markdown]
# Source: Thakur, R. (2023, March 9). Beginner’s Guide to VGG16 Implementation in Keras. Built In. Retrieved April 14, 2023, from https://builtin.com/machine-learning/vgg16

# %% [markdown]
# From: Ahmad, F., & Sahil, N. (2019) Plot_CM.py [Source Code] (Accessed April 23, 2023) https://github.com/sahilsharma884/Music-Genre-Classification/blob/master/Plot_CM.py

# %% [markdown]
# From: Ahmad, F., & Sahil, N. (2019) CNN_Model.py [Source Code] (Accessed April 23, 2023) https://github.com/sahilsharma884/Music-Genre-Classification/blob/master/CNN_Model.py
